# %% [markdown]
# # FIFA Statistics

# %% [markdown]
# #### Yejee Park 2751917
# #### Kathy Wang 2785678
# #### Jenny Jang 2751704

# %% [markdown]
# ## Introduction:
# - describe topic
#     - FIFA (Fédération Internationale de Football Association) is the federation etc etc etc
# - data analysis question / relevance
#     - Question: Did male player's overall performance change from the year 2021- 2022?
#     - Because FIFA is a world renowned association, the world cup is a thrilling event millions of people are excited to watch. In addition to the world cup being a form of entertainment, athletes are always continuously striving to improve every season. Improving signifies effective training/strategy, and tells the players/team if there are areas of improvement. This can be gauged by comparing the overall rating of the players.
# - summary of results and coming structure of project

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
