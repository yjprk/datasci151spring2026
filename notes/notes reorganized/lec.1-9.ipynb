# %% [markdown]
# <font size = "5">
# text (lecutre 1):
# <br>
# <font size = "3">
# font size:
# <br>
#     - less # means smaller size
# <br>
#     - or double click to see other method
# <br>
# - print("")

# %% [markdown]
# <font size = "5">
# intro to jupyter (lecture 2):
# <br>
# <font size = "3">
# - importing math, plt, stats
# <br>
# - csv dataset => name = pd.read_csv("folder/file.csv")
# <br>
# creating tables
# <br>
# - shows one column => display(carfeatures['cylinders'])
# <br>
# - frequency table => table = pd.crosstab(index = carfeatures['cylinders'],columns = "count")
# <br>
# - two columns into 1 (crosstab) => table_2 = pd.crosstab(index = carfeatures['cylinders'],columns = carfeatures['mpg'])
# <br>
# # "index" is the category, # "columns" is a custom title
# <br>
# - describe => display(carfeatures.describe())  count, mean, std, min, 25% quantile, 50%, 75%, max
# <br>
# - round to two decimal points => display(round(carfeatures.describe(), 2))

# %% [markdown]
# <font size = "5">
# Objects, Varaibles, and Lists (Lecture 4):
# <br>
# <font size = "3">
# objects:
# <br>
# - type() tells you what kind of object the input is int, float (# w/ decimals), and str
# <br>
# variables:
# <br>
# - variables = # or "str"
# <br>
# lists:
# <br>
# - lists are always used w/ [ ]
# <br>
# - length => print(len(variable))
# <br>
# - individual elements => print(variable[0])
# <br>
# - change one element in a list => favorite_movies[4] = "The Wailing"
# <br>
# - more in lecture page

# %% [markdown]
# <font size = "5">
# Sequence Objects (lecture 5 and 6):
# <br>
# <font size = "3">
# tuple and strings
# <br>
# - tuple: ( ), immutable
# <br>
# - strings: sequence of characters, immutable
# <br>
# - lists: [ ], mutable
# <br>
# concatenation
# <br>
# - add str, lists, and tuples
# <br>
# numpy arrays:
# <br>
# - array_of_numbers = np.array([5.6, 2.9, 9.7, -10, 0, 3])
# <br>
# - print(a + 2)
# <br>
# - np.log,exp(e) same thing,sin,cos,sqrt,pi

# %% [markdown]
# <font size = "5">
# Boolean and If/Else Statements(lecture 07 and supplemental):
# <br>
# <font size = "3">
# Boolean:
# - object true/false, and we assign directly x=true
# <br>
# - used for comparisons (==, !=)
# <br>
# In Keyword:
# <br>
# - a character, object, number appears in something
# <br>
# - "not" "and" "or" used to find true/false
# <br>
# If/Else/Elif:
# <br>
# - check lecture 07
# <br>
# ---
# supplemental functions
# <br>
# - print(favorite_movies[-1]): last element
# <br>
# - append method adds to a list: my_list.append("")
# <br>
# - sort method: string_list.sort()
# <br>
# - copy method: copy_of_list = list_of_floats.copy()
# <br>
#                 list_of_floats[0] = "Nothing"
# <br>
# - colors.reverse()
# <br>
# - pink_count = fav_colors.count("pink")
# <br>
# numpy:
# <br>
# - check numpy mistakes that can be made when making copies of arrays
# <br>
# - z.sort()
# <br>
#     - can make sorted copy
# <br>
# - print(c_vec.mean())
# <br>
# - random number where mean = 0 sd = 1,size=number of results np.random.normal(loci, scale, size=10),
# <br>
#     - np.random(loc, scale, size) , loc=mean, scale=sd
# <br>
# - seed: "pre generated set"

# %% [markdown]
# <font size ="5">
# Loops
# <br>
# <font size = "3">
# - debug
# <br>
# - for loops: allows you to repeat code for each item in a sequence
# <br>
# - while loops:

# %% [markdown]
# <font size = "5">
# PLOTS:
# <br>
# <font size = "3">
# - bar plot
# <br>
# categories = [],
# count = []
# <br>
# plt.bar(x=categories, height = count)
# <br>
# plt.title("Favorite Colors")
# <br>
# plt.ylabel("Count")
# <br>
# plt.show()
# <br>
# - scatter plot
# <br>
# plt.scatter(x=x_vals, y=y_vals)

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)

for letter in "python":
    print(letter)

for i in range(5):
    print(i)
# Out:
# apple
# banana
# cherry
# p
# y
# t
# h
# o
# n
# 0
# 1
# 2
# 3
# 4
