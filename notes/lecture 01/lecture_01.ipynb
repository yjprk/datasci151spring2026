# %% [markdown]
# These are where lecture notes will be written, describing what's happening in the code cells

# %% [markdown]
# There are different ways of changing fonts...
#
#
# <font size = "4">
#
# Font size 4
#
# other text
# other text
#
# <font size = "10">
# Font size 10
#
# other text
# <font size = "1">
#
# small text

# %% [markdown]
# # Big text
#
# ## slightly smaller
#
#
# ###### smallest

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Additional notes here, explaining something

# %%
print("Another python command!")
# Out:
# Another python command!
