# %% [markdown]
# <font size = "4">
# other text

# %% [markdown]
# # big text
# ## slightly smaller
# ##### smallest

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(log2(8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(log2(8))
#
# NameError: name 'log2' is not defined

# %%
import math 
print(math.log2(8))
# Out:
# 3.0

# %%
import statistics
