# %%
list_of_numbers = [5,3,2,0] # bracket is list 
tuple_of_numbers = (5,3,2,0) # parenthesis is tuple

print (list_of_numbers) 
print(tuple_of_numbers)
print()

print(type(list_of_numbers))
print(type(tuple_of_numbers))
# Out:
# [5, 3, 2, 0]
# (5, 3, 2, 0)
#
# <class 'list'>
# <class 'tuple'>

# %%
list_of_numbers[3] = 55 # lists can change , tuples CANNOT 
print(list_of_numbers)
# Out:
# [5, 3, 2, 55]

# %%
print(tuple_of_numbers[3])
tuple_of_numbers[3] = 5
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 print(tuple_of_numbers[3])
# ----> 2 tuple_of_numbers[3] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple_of_numbers = 5,3,2,0 # you can create a tuple without using parenthesis, for lists you MUST have brackets though 
print(tuple_of_numbers)
print()
print(type(tuple_of_numbers))
# Out:
# (5, 3, 2, 0)
#
# <class 'tuple'>

# %%
my_name = "Yejee Park"
print(type(my_name))
print(len(my_name)) # length of characters
print()
print(my_name[0]) # Character zero of string 
print(my_name[4]) # Character four of string
print(my_name[5]) # Character five of string (white space)
print(my_name[6]) # Character six of string 
print(my_name[9]) # causes error because my name doesn't have 10 characters 
# command forward slash makes things a comment
# Out:
# <class 'str'>
# 10
#
# Y
# e
#
# P
# k

# %%
my_name[0] = "y" # you cannot change strings, they are immutable 
# tuples and strings are basically the same thing except strings are for letters and tuples for numbers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 my_name[0] = "y" # you cannot change strings, they are immutable
#       2 # tuples and strings are basically the same thing except strings are for letters and tuples for numbers
#
# TypeError: 'str' object does not support item assignment

# %%
list_1 = [2,3,5,11]
list_2 = [1, -4, 2, 0]

list_3 = list_1 + list_2 # concatenation: combining all of the elements into one 
print(list_3)
# Out:
# [2, 3, 5, 11, 1, -4, 2, 0]

# %%
first_name = "Yejee " # added a white space after for a space in between the two words 

last_name = "Park"
my_name = first_name + last_name
print(my_name)
# Out:
# Yejee Park

# %%
tuple_1 = (1,2,0,9,8)
tuple_2 = (-1, -50)
print(tuple_1 + tuple_2)
# Out:
# (1, 2, 0, 9, 8, -1, -50)

# %%
my_list = ["sequence", "Python", 1.2, 0] + [5, -3]
print(my_list)

my_name = "Yejee" + " " + "Park" + "!"
print(my_name)

my_tuple = (1,) + (2, 3, 4, 5, 6, 7, 8, 9) # we need the comma after the 1 
print(my_tuple)
# Out:
# ['sequence', 'Python', 1.2, 0, 5, -3]
# Yejee Park!
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
z = (1) 
print(type(z))

z = 1, 
print(type(z)) 
# for a tuple, comma is the most important part
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
list_of_floats = [2.3, -1.0, 5.1, 9.9]

new_variable = list_of_floats[2]
print(new_variable) 

list_of_floats[2] = 0.0 

print(list_of_floats)

print(new_variable)
# Out:
# 5.1
# [2.3, -1.0, 0.0, 9.9]
# 5.1

# %%
list_of_floats = [2.3, -1.0, 5.1, 9.9]

# Here, we are using the *entire list* with the assignment operator, 
# so we are NOT making a distinct new variable

list_of_numbers = list_of_floats

print(list_of_numbers)

list_of_floats[2] = 0.0

print(list_of_numbers)
# Out:
# [2.3, -1.0, 5.1, 9.9]
# [2.3, -1.0, 0.0, 9.9]

# %%
import matplotlib.pyplot as plt

# %%
categories = ["Freshman", "Sophomore", "Junior", "Senior"]
count = [22,21,31,25]
plt.bar(x=categories, height = count)
plt.show()

# %%
import numpy as np

# %%
list_of_numbers = [5.6, 2.9, 9.7, -10, 0, 3]

array_of_numbers = np.array(list_of_numbers)

print(type(array_of_numbers))
print(array_of_numbers)
display(array_of_numbers)
# Out:
# <class 'numpy.ndarray'>
# [  5.6   2.9   9.7 -10.    0.    3. ]
# array([  5.6,   2.9,   9.7, -10. ,   0. ,   3. ])

# %%
array_of_numbers = np.array([5.6, 2.9, 9.7, -10, 0, 3])


# you can access elements of arrays in the same way as lists:
print(array_of_numbers[0])
print(array_of_numbers[4])
# Out:
# 5.6
# 0.0

# %%
list_1 = [2, 3, 5, 11]
list_2 = [1, -4, 2, 0]

# The "+" operation concatenates the lists
print(list_1 + list_2)
# Out:
# [2, 3, 5, 11, 1, -4, 2, 0]

# %%
array_1 = np.array([2, 3, 5, 11])
array_2 = np.array([1, -4, 2, 0])

# The "+" operation adds the elements of the two arrays together
print(array_1 + array_2)
# Out:
# [ 3 -1  7 11]

# %%
a = np.array([3, 11, -2.2])
print(a + 2) # adds 2 to every number in the array
# Out:
# [ 5.  13.  -0.2]

# %%
print(np.log(2)) # log is always the natural log (ln)
print(np.exp(2)) # e^x
print(np.sin(2))
print(np.cos(2))
print(np.sqrt(2))
# Out:
# 0.6931471805599453
# 7.38905609893065
# 0.9092974268256817
# -0.4161468365471424
# 1.4142135623730951

# %%
print(np.pi) # pi
print(np.e) # euiler's number 
print(np.exp(1))
# Out:
# 3.141592653589793
# 2.718281828459045
# 2.718281828459045

# %% [markdown]
# #### PRACTICE FROM HERE ON OUT

# %%
# Create list of equally spaced points from -1.5 to 1.5
# We'll choose points 0.25 apart
x_vals = [-1.5, -1.25, -1, -0.75, -0.5, -0.25, 0, 0.25, 0.5, 0.75, 1, 1.25, 1.5]

# Convert to numpy array
x_vals = np.array(x_vals)

# Create new numpy array with the function evaluated at the same points
y_vals = x_vals**3 - 2*x_vals + 0.5
# ** -> raise everything to the 3rd power
# * -> multiply 

# Use plt.scatter to create scatter plot
plt.scatter(x = x_vals, y = y_vals)
plt.show()

# %%
# convert list to numpy array right away
t_vals = np.array( [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5] )

# Evaluate function and create new array 
g_of_t = np.exp(t_vals**2) - np.sqrt(t_vals) + 1

# Use plt.scatter to create scatter plot
plt.scatter(x = t_vals, y = g_of_t)
plt.show()

# %% [markdown]
# ## Exercises:
# #### on the other page
